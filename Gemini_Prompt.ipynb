# %% [markdown]
# <a href="https://colab.research.google.com/github/morampudisunil/sunil/blob/main/Gemini_Prompt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import google.generativeai as genai

# %%
GOOGLE_API_KEY='AIzaSyD3tCe3Ge45O35m4vPPgR1jsZMx1Dn7hfU'

genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-flash-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
model = genai.GenerativeModel('gemini-pro')
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
# )

# %%
chat = model.start_chat(history=[])
while True:
    user_input = input("You: ")
    if user_input.lower() == "done":
        print("Exiting...")
        break
    else:
        response = chat.send_message(user_input)
        print("AI: ", response.text)
# Out:
# You: who is world richest person
# AI:  Elon Musk
# You: who is country richest person
# AI:  Bernard Arnault
# You: jio reliance owner
# AI:  Mukesh Ambani
# You: her is in which place
# AI:  10th
# You: country 10th richest person
# AI:  Warren Buffett
# You: mukesh ambani richest place in country
# AI:  1st
# You: ambani sons names
# AI:  * Akash Ambani
# * Anant Ambani
# You: anant wife name
# AI:  Radhika Merchant
# You: she is from where
# AI:  Mumbai, India
# You: summer best tourists places in india
# AI:  * **Manali, Himachal Pradesh:** A hill station nestled in the Himalayas, Manali offers stunning views of snow-capped peaks, lush green valleys, and cascading waterfalls. It's a popular destination for adventure activities like skiing, snowboarding, and paragliding.
#
# ...
